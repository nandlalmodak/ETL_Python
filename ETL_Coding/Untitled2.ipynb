# %%
import pandas as pd

# %%
df =pd.read_csv('Data_emp.csv')

# %%
df
# Out:
#    emp_id name  salary dept_name country
# 0     1.0    A     200        IT     USA
# 1     2.0    B     100        HR   India
# 2     3.0    C     400        IT   India
# 3     4.0    D     500        IT   India
# 4     5.0    E     400        HR   India
# 5     6.0    F     600     Admin     USA
# 6     7.0    G     700        IT     USA
# 7     NaN  NaN     100       NaN     NaN
# 8     9.0    J     500       NaN     USA
# 9     1.0    A     200        IT     USA

# %%
g=df.groupby('dept_name')

# %%
g['dept_name'].count()
# Out:
# dept_name
# Admin    1
# HR       2
# IT       5
# Name: dept_name, dtype: int64

# %%
len(df)
# Out:
# 10

# %%
df.columns
# Out:
# Index(['emp_id', 'name', 'salary', 'dept_name', 'country'], dtype='object')

# %%
g=df.groupby('dept_name')

# %%
g['dept_name'].sum()
# Out:
# dept_name
# Admin         Admin
# HR             HRHR
# IT       ITITITITIT
# Name: dept_name, dtype: object

# %%
g['emp_id'].count()
# Out:
# dept_name
# Admin    1
# HR       2
# IT       5
# Name: emp_id, dtype: int64

# %%
g['name'].count()
# Out:
# dept_name
# Admin    1
# HR       2
# IT       5
# Name: name, dtype: int64

# %%
df['emp_id'].unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6.,  7., nan,  9.])

# %%
len(df['emp_id'].unique())
# Out:
# 9

# %%
df['emp_id']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    NaN
# 8    9.0
# 9    1.0
# Name: emp_id, dtype: float64

# %%
df['emp_id']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    7.0
# 7    NaN
# 8    9.0
# 9    1.0
# Name: emp_id, dtype: float64

# %%
len(df['emp_id'])
# Out:
# 10

# %%
df['emp_id'].unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  6.,  7., nan,  9.])

# %%
len(df['emp_id'].unique())
# Out:
# 9

# %%
df.shape
# Out:
# (10, 5)

# %%
df.iloc[[2,4],[1]]
# Out:
#   name
# 2    C
# 4    E

# %%
df['salary'].nlargest(2)
# Out:
# 6    700
# 5    600
# Name: salary, dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# dtype: bool

# %%
dup=df[df.duplicated()]

# %%
dup
# Out:
#    emp_id name  salary dept_name country
# 9     1.0    A     200        IT     USA

# %%
dup2=df[df['emp_id'].duplicated()]

# %%
dup2
# Out:
#    emp_id name  salary dept_name country
# 9     1.0    A     200        IT     USA
