# %%
import pandas as pd

# %%
df=pd.read_csv('Data_emp.csv')

# %%
print(df)
# Out:
#    emp_id name  salary dept_name country
# 0     1.0    A     200        IT     USA
# 1     2.0    B     100        HR   India
# 2     3.0    C     400        IT   India
# 3     4.0    D     500        IT   India
# 4     5.0    E     400        HR   India
# 5     6.0    F     600     Admin     USA
# 6     7.0    G     700        IT     USA
# 7     NaN  NaN     100       NaN     NaN
# 8     9.0    J     500       NaN     USA
# 9     1.0    A     200        IT     USA

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df2 = spark.read.csv("Data_emp.csv", header=True, inferSchema=True)

df2.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 from pyspark.sql import SparkSession
# ----> 3 spark = SparkSession.builder.getOrCreate()
#       5 df2 = spark.read.csv("Data_emp.csv", header=True, inferSchema=True)
#       7 df2.show()
#
# File C:\Python_Software\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File C:\Python_Software\Lib\site-packages\pyspark\sql\session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     632 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     634 if jsparkSession is None:
#     635     if (
# --> 636         jSparkSessionClass.getDefaultSession().isDefined()
#     637         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     638     ):
#     639         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     640         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("TestApp") \
    .config("spark.driver.host", "127.0.0.1") \
    .getOrCreate()

print("Spark started")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       1 from pyspark.sql import SparkSession
#       3 spark = SparkSession.builder \
#       4     .master("local[*]") \
#       5     .appName("TestApp") \
#       6     .config("spark.driver.host", "127.0.0.1") \
# ----> 7     .getOrCreate()
#       9 print("Spark started")
#
# File C:\Python_Software\Lib\site-packages\pyspark\sql\session.py:560, in SparkSession.Builder.getOrCreate(self)
#     557     sc = SparkContext.getOrCreate(sparkConf)
#     558     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559     # by all sessions.
# --> 560     session = SparkSession(sc, options=self._options)
#     561 else:
#     562     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File C:\Python_Software\Lib\site-packages\pyspark\sql\session.py:636, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     632 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     634 if jsparkSession is None:
#     635     if (
# --> 636         jSparkSessionClass.getDefaultSession().isDefined()
#     637         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     638     ):
#     639         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     640         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable
