# %%
import pandas as pd

# %%
import pytest

# %%
df= pd.read_csv("C:/ETL_Python/Data.csv")

# %%
#df= pd.read_csv('Data.csv')

# %%
print(df)
# Out:
#      SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0     NIFTY 50  25,546.85  25,781.50  25,508.60      25,585.30  25,709.85
# 1   ASIANPAINT      2,421      2,544      2,421       2,409.70   2,507.80
# 2          M&M      3,561      3,656   3,560.10       3,560.80      3,656
# 3   BHARTIARTL   1,973.60   2,034.30   1,970.30       1,967.40   2,012.90
# 4    MAXHEALTH      1,188   1,212.80   1,178.70       1,175.30      1,201
# 5   HINDUNILVR   2,565.50      2,615      2,560       2,561.50   2,603.40
# 6          ITC     405.35     413.85     405.25         405.15      411.4
# 7     RELIANCE      1,401   1,423.30   1,399.10       1,398.30   1,419.10
# 8   TATACONSUM   1,152.20   1,173.50   1,142.50       1,149.30   1,165.70
# 9    ICICIBANK      1,412   1,439.60   1,410.90       1,417.30   1,436.60
# 10     DRREDDY      1,245      1,262   1,238.10       1,240.20   1,256.60
# 11   SUNPHARMA   1,658.20      1,692   1,656.70          1,659   1,678.10
# ...

# %%
df= pd.read_excel('employees_details.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File C:\Python_Software\Lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File C:\Python_Software\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1398, in _gcd_import(name, package, level)
#    1397     name = _resolve_name(name, package, level)
# -> 1398 return _find_and_load(name, _gcd_import)
#
# File <frozen importlib._bootstrap>:1371, in _find_and_load(name, import_)
#    1370     if module is _NEEDS_LOADING:
# -> 1371         return _find_and_load_unlocked(name, import_)
# ...
