# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv')

# %%
df.shape
# Out:
# (51, 15)

# %%
df.iloc[5]
# Out:
# SYMBOL \n              HINDUNILVR
# OPEN \n                  2,565.50
# HIGH \n                  2,615.00
# LOW \n                   2,560.00
# PREV. CLOSE \n           2,561.50
# LTP \n                   2,603.40
# INDICATIVE CLOSE \n             -
# CHNG \n                      41.9
# %CHNG \n                     1.64
# VOLUME \n(shares)       20,50,690
# VALUE \n (₹ Crores)        533.15
# 52W H \n                 2,797.55
# 52W L \n                 2,136.00
# 30 D   %CHNG \n              0.88
# 365 D % CHNG \n             -6.38
# Name: 5, dtype: object
